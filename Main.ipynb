# %% [markdown]
# ### Imports

# %%
import sys
import pandas as pd
sys.path.append('Scripts')
import helper
import grapher

# %% [markdown]
# ### Data Source

# %% [markdown]
# Main Data Source:
# https://www.bls.gov/cex/tables.htm
#
# Definition for a Consumer Unit:
# https://www.bls.gov/opub/hom/cex/concepts.htm

# %% [markdown]
# ### Get Data From Helper Functions

# %%
data = helper.get_data('Data')

# %%
columns = ["25-34 years", "35-44 years", "45-54 years", "55-64 years", "65-74 years"]

# %% [markdown]
# ### Analysis

# %% [markdown]
# #### Difference Between Income After Taxes and Average Annual Expenditures

# %%
df_result = helper.get_helper(data, 'Income after taxes', 1) - helper.get_helper(data, 'Average annual expenditures', 1)
grapher.graph_all(df_result, "Spending Gap", columns)
df_result
# Out:
# Error in get_heat_plot: 'bool' object has no attribute 'all'
#       All consumer units  Under 25 years  25-34 years  35-44 years  \
# Year
# 2012               11928            2259         7893        18307
# 2013                5252           -3814         5091        10368
# 2014                4869           -3661         5075         9983
# 2015                4470           -3185         5212         7646
# 2016                6864           12195         6024        12827
# 2017                3546           -3669         5820         6575
# 2018                6017           -2246         8061        11188
# 2019                8451           -3715        10759        14596
# 2020               13615            4424        15632        18536
# 2021               11815            2326        14309        18204
# 2022               10228              80        13028        17427
# 2023               10589            1718        13072        18136
#
# ...

# %%
df_result = helper.get_helper(data, 'Income after taxes', 1) / helper.get_helper(data, 'Average annual expenditures', 1)
grapher.graph_all(df_result, "Income To Expenditure Ratio", columns)
df_result
# Out:
# Error in get_heat_plot: 'bool' object has no attribute 'all'
#       All consumer units  Under 25 years  25-34 years  35-44 years  \
# Year
# 2012            1.231873        1.071917     1.159313     1.315263
# 2013            1.102779        0.874428     1.105871     1.176375
# 2014            1.091018        0.886230     1.102428     1.159697
# 2015            1.079853        0.902887     1.100111     1.117029
# 2016            1.119768        1.354115     1.114009     1.193050
# 2017            1.059041        0.890898     1.105197     1.095243
# 2018            1.098278        0.929898     1.142781     1.157139
# 2019            1.134066        0.905454     1.188331     1.194899
# 2020            1.221981        1.116207     1.271196     1.249960
# 2021            1.176533        1.055298     1.223910     1.228372
# 2022            1.140173        1.001726     1.191918     1.202524
# 2023            1.137021        1.034665     1.181892     1.199430
#
# ...

# %% [markdown]
# #### Home Ownership Rates

# %%
df = helper.get_helper(data, 'Homeowner', 0)
grapher.graph_all(df, "Home Owner Rates", columns)
df
# Out:
# Error in get_heat_plot: 'bool' object has no attribute 'all'
#       All consumer units  Under 25 years  25-34 years  35-44 years  \
# Year
# 2012                  64              15           40           62
# 2013                  64              14           40           62
# 2014                  63              11           39           58
# 2015                  62              14           39           57
# 2016                  62              17           37           57
# 2017                  63              13           41           54
# 2018                  63              13           41           58
# 2019                  64              17           41           60
# 2020                  66              17           43           62
# 2021                  65              18           44           60
# 2022                  65              18           43           62
# 2023                  65              15           42           64
#
# ...

# %% [markdown]
# #### Housing Costs

# %%
df = helper.get_helper(data, 'Housing', 1)
grapher.graph_all(df, "Housing Costs", columns)
# Out:
# Error in get_heat_plot: 'bool' object has no attribute 'all'

# %%
df = helper.get_helper(data, 'Housing', 1) / helper.get_helper(data, 'Income after taxes', 1)
grapher.graph_all(df, "Ratio of Housing Costs To Income", columns)
# Out:
# Error in get_heat_plot: 'bool' object has no attribute 'all'

# %% [markdown]
# #### Food Expenditures

# %%
df = helper.get_helper(data, 'Food', 2)
grapher.graph_all(df, "Share of Expenditure On Food", columns)
df
# Out:
# Error in get_heat_plot: 'bool' object has no attribute 'all'
#       All consumer units  Under 25 years  25-34 years  35-44 years  \
# Year
# 2012                12.8            14.0         13.1         13.3
# 2013                12.9            15.5         12.9         13.5
# 2014                12.6            13.7         13.4         12.9
# 2015                12.5            14.9         12.7         13.5
# 2016                12.6            13.2         13.1         13.1
# 2017                12.9            14.2         13.4         13.6
# 2018                12.9            14.8         13.0         13.8
# 2019                13.0            14.9         12.9         13.0
# 2020                11.9            11.9         12.2         12.6
# 2021                12.4            13.2         12.4         12.3
# 2022                12.8            12.7         13.1         12.8
# 2023                12.9            12.0         13.5         13.2
#
# ...

# %%
df = helper.get_helper(data, 'Food', 1)
grapher.graph_all(df, "Total Expenditure On Food", columns)
df
# Out:
# Error in get_heat_plot: 'bool' object has no attribute 'all'
#       All consumer units  Under 25 years  25-34 years  35-44 years  \
# Year
# 2012                6599            4412         6513         7701
# 2013                6602            4698         6197         7920
# 2014                6759            4423         6632         8063
# 2015                7023            4890         6636         8844
# 2016                7203            4551         6914         8700
# 2017                7729            4759         7390         9376
# 2018                7923            4748         7343         9820
# 2019                8169            5835         7370         9760
# 2020                7316            4526         7048         9343
# 2021                8289            5566         7942         9806
# 2022                9343            5898         8914        11023
# 2023                9985            5953         9704        12006
#
# ...

# %%
df = helper.get_helper(data, 'Food', 1) / helper.get_helper(data, 'Income after taxes', 1)
grapher.graph_all(df, "Ratio Of Expenditure On Food To Income", columns)
df
# Out:
# Error in get_heat_plot: 'bool' object has no attribute 'all'
#       All consumer units  Under 25 years  25-34 years  35-44 years  \
# Year
# 2012            0.104134        0.131037     0.113394     0.100830
# 2013            0.117156        0.176889     0.116533     0.114530
# 2014            0.115808        0.155095     0.121416     0.111221
# 2015            0.116183        0.165136     0.115864     0.121184
# 2016            0.112240        0.097592     0.117461     0.109750
# 2017            0.121514        0.158845     0.120860     0.124006
# 2018            0.117830        0.159366     0.113813     0.119195
# 2019            0.114273        0.164006     0.108563     0.109067
# 2020            0.097613        0.106509     0.096188     0.100796
# 2021            0.105266        0.125391     0.101542     0.100147
# 2022            0.112302        0.127005     0.110170     0.106527
# 2023            0.113635        0.116093     0.114247     0.110071
#
# ...

# %%
df = helper.get_helper(data, 'Food away from home', 1)
grapher.graph_all(df, "Expenditure On Eating Out", columns)
df
# Out:
# Error in get_heat_plot: 'bool' object has no attribute 'all'
#       All consumer units  Under 25 years  25-34 years  35-44 years  \
# Year
# 2012                2678            1883         2833         3210
# 2013                2625            2096         2639         3280
# 2014                2787            1926         2921         3388
# 2015                3008            2347         3097         3900
# 2016                3154            2250         3165         3975
# 2017                3365            2362         3416         4249
# 2018                3459            2336         3450         4395
# 2019                3526            3092         3534         4302
# 2020                2375            1923         2665         3141
# 2021                3030            2485         3444         3607
# 2022                3639            2551         3738         4250
# 2023                3933            2804         4167         4795
#
# ...

# %%
df = helper.get_helper(data, 'Food away from home', 2)
grapher.graph_all(df, "Share Of Eating Out", columns)
df
# Out:
# Error in get_heat_plot: 'bool' object has no attribute 'all'
#       All consumer units  Under 25 years  25-34 years  35-44 years  \
# Year
# 2012                 5.2             6.0          5.7          5.5
# 2013                 5.1             6.9          5.5          5.6
# 2014                 5.2             6.0          5.9          5.4
# 2015                 5.4             7.2          5.9          6.0
# 2016                 5.5             6.5          6.0          6.0
# 2017                 5.6             7.0          6.2          6.2
# 2018                 5.6             7.3          6.1          6.2
# 2019                 5.6             7.9          6.2          5.7
# 2020                 3.9             5.1          4.6          4.2
# 2021                 4.5             5.9          5.4          4.5
# 2022                 5.0             5.5          5.5          4.9
# 2023                 5.1             5.7          5.8          5.3
#
# ...

# %%
df = helper.get_helper(data, 'Alcoholic beverages', 2)
grapher.get_bar_plot(df, "Share Of Spending On Alcoholic Beverages", df["All consumer units"])
df
# Out:
#       All consumer units  Under 25 years  25-34 years  35-44 years  \
# Year
# 2012                 0.9             1.1          1.1          0.9
# 2013                 0.9             1.2          1.0          0.8
# 2014                 0.9             0.9          1.1          0.8
# 2015                 0.9             0.8          1.0          1.1
# 2016                 0.8             0.7          1.0          0.8
# 2017                 0.9             0.9          1.0          0.9
# 2018                 1.0             0.8          1.1          1.0
# 2019                 0.9             0.8          0.9          0.7
# 2020                 0.8             0.6          0.8          0.7
# 2021                 0.8             0.8          1.0          0.7
# 2022                 0.8             0.9          0.9          0.8
# 2023                 0.8             0.7          0.9          0.7
#
#       45-54 years  55-64 years  65 years and older  65-74 years  \
# Year
# ...

# %%
df = helper.get_helper(data, 'Alcoholic beverages', 1)
grapher.get_bar_plot(df, "Spending On Alcoholic Beverages", df["All consumer units"])
df
# Out:
#       All consumer units Under 25 years  25-34 years  35-44 years  \
# Year
# 2012                 451            354          564          501
# 2013                 445            379          489          443
# 2014                 463            303          529          505
# 2015                 515            250          543          697
# 2016                 484            230          539          538
# 2017                 558            317          573          624
# 2018                 583            271          633          725
# 2019                 579            327          525          544
# 2020                 478            225          481          551
# 2021                 554            346          663          596
# 2022                 583            394          622          688
# 2023                 637            329          654          681
#
#       45-54 years  55-64 years  65 years and older  65-74 years  \
# Year
# ...

# %% [markdown]
# #### Entertainment

# %%
df = helper.get_helper(data, 'Entertainment', 2)
grapher.graph_all(df, "Share of Entertainment Expenditures", columns)
grapher.get_bar_plot(df, "Share of Entertainment Expenditures", df["All consumer units"])
df
# Out:
# Error in get_heat_plot: 'bool' object has no attribute 'all'
#       All consumer units  Under 25 years  25-34 years  35-44 years  \
# Year
# 2012                 5.1             4.0          4.8          5.6
# 2013                 4.9             4.1          4.6          5.0
# 2014                 5.1             4.1          4.9          5.4
# 2015                 5.1             4.1          4.8          4.9
# 2016                 5.1             4.2          4.9          5.3
# 2017                 5.3             4.4          4.8          5.8
# 2018                 5.3             4.4          4.5          5.0
# 2019                 4.9             3.5          4.2          4.9
# 2020                 4.7             3.3          4.5          4.9
# 2021                 5.3             4.0          5.0          5.4
# 2022                 4.7             4.5          4.2          5.1
# 2023                 4.7             3.7          4.2          5.2
#
# ...

# %%
df = helper.get_helper(data, 'Entertainment', 1)
grapher.graph_all(df, "Total Expenditure On Entertainment", columns)
df
# Out:
# Error in get_heat_plot: 'bool' object has no attribute 'all'
#       All consumer units  Under 25 years  25-34 years  35-44 years  \
# Year
# 2012                2605            1257         2382         3232
# 2013                2482            1243         2214         2958
# 2014                2728            1319         2418         3372
# 2015                2842            1354         2475         3192
# 2016                2913            1454         2564         3509
# 2017                3203            1488         2644         4001
# 2018                3226            1409         2547         3572
# 2019                3090            1389         2395         3661
# 2020                2912            1266         2570         3628
# 2021                3568            1700         3198         4267
# 2022                3458            2075         2884         4361
# 2023                3635            1835         3008         4694
#
# ...

# %%
df = helper.get_helper(data, 'Entertainment', 1) / helper.get_helper(data, 'Income after taxes', 1)
grapher.graph_all(df, "Ratio of Entertainment Expenditures To Income", columns)
grapher.get_bar_plot(df, "Ratio of Entertainment Expenditures To Income", df["All consumer units"])
df
# Out:
# Error in get_heat_plot: 'bool' object has no attribute 'all'
#       All consumer units  Under 25 years  25-34 years  35-44 years  \
# Year
# 2012            0.041108        0.037333     0.041472     0.042317
# 2013            0.044045        0.046801     0.041634     0.042775
# 2014            0.046741        0.046251     0.044268     0.046514
# 2015            0.047016        0.045725     0.043213     0.043738
# 2016            0.045392        0.031180     0.043560     0.044266
# 2017            0.050357        0.049666     0.043241     0.052917
# 2018            0.047977        0.047293     0.039477     0.043357
# 2019            0.043225        0.039041     0.035279     0.040911
# 2020            0.038853        0.029792     0.035074     0.039140
# 2021            0.045312        0.038298     0.040888     0.043578
# 2022            0.041565        0.044682     0.035644     0.042145
# 2023            0.041368        0.035785     0.035414     0.043035
#
# ...

# %%
df = helper.get_helper(data, 'Apparel and services', 2)
grapher.graph_all(df, "Share of Apparel Expenditures", columns)
grapher.get_bar_plot(df, "Share of Apparel Expenditures", df["All consumer units"])
df
# Out:
# Error in get_heat_plot: 'bool' object has no attribute 'all'
#       All consumer units  Under 25 years  25-34 years  35-44 years  \
# Year
# 2012                 3.4             4.0          4.2          3.9
# 2013                 3.1             5.0          3.8          3.3
# 2014                 3.3             4.0          3.9          3.6
# 2015                 3.3             3.9          3.6          4.0
# 2016                 3.1             3.5          3.7          3.8
# 2017                 3.1             3.9          3.7          3.4
# 2018                 3.0             3.5          3.8          3.4
# 2019                 3.0             3.6          3.3          3.3
# 2020                 2.3             3.1          3.0          2.7
# 2021                 2.6             3.5          3.2          2.9
# 2022                 2.7             2.6          3.3          3.1
# 2023                 2.6             2.9          2.9          3.3
#
# ...

# %%
df = helper.get_helper(data, 'Apparel and services', 1)
grapher.graph_all(df, "Total Expenditure On Apparel", columns)
df
# Out:
# Error in get_heat_plot: 'bool' object has no attribute 'all'
#       All consumer units  Under 25 years  25-34 years  35-44 years  \
# Year
# 2012                1736            1246         2061         2264
# 2013                1604            1513         1832         1960
# 2014                1786            1285         1914         2250
# 2015                1846            1271         1864         2584
# 2016                1803            1216         1942         2508
# 2017                1833            1315         2042         2377
# 2018                1866            1128         2126         2421
# 2019                1883            1407         1878         2488
# 2020                1434            1164         1703         2010
# 2021                1754            1488         2023         2302
# 2022                1945            1184         2249         2632
# 2023                2041            1418         2083         2959
#
# ...

# %%
df = helper.get_helper(data, 'Apparel and services', 1) / helper.get_helper(data, 'Income after taxes', 1)
grapher.graph_all(df, "Ratio of Apparel Expenditures To Income", columns)
grapher.get_bar_plot(df, "Ratio of Apparel Expenditures To Income", df["All consumer units"])
df
# Out:
# Error in get_heat_plot: 'bool' object has no attribute 'all'
#       All consumer units  Under 25 years  25-34 years  35-44 years  \
# Year
# 2012            0.027395        0.037006     0.035883     0.029643
# 2013            0.028464        0.056968     0.034450     0.028343
# 2014            0.030601        0.045059     0.035041     0.031037
# 2015            0.030539        0.042922     0.032545     0.035407
# 2016            0.028095        0.026076     0.032992     0.031638
# 2017            0.028818        0.043892     0.033396     0.031438
# 2018            0.027751        0.037861     0.032952     0.029386
# 2019            0.026340        0.039547     0.027664     0.027803
# 2020            0.019133        0.027392     0.023242     0.021685
# 2021            0.022275        0.033522     0.025865     0.023510
# 2022            0.023379        0.025496     0.027796     0.025436
# 2023            0.023228        0.027653     0.024523     0.027128
#
# ...

# %% [markdown]
# #### Transportation

# %%
df = helper.get_helper(data, 'Transportation', 1)
grapher.graph_all(df, "Average of Transportation Costs", columns)
df
# Out:
# Error in get_heat_plot: 'bool' object has no attribute 'all'
#       All consumer units  Under 25 years  25-34 years  35-44 years  \
# Year
# 2012                8998            6410         9724         9991
# 2013                9004            5672         9183        10519
# 2014                9073            6167         8908        10617
# 2015                9503            6320         9777        10945
# 2016                9049            6042         9124        10352
# 2017                9576            6655         9115        11054
# 2018                9761            5526        10307        11840
# 2019               10742            8305        10296        13685
# 2020                9826            7300        10277        12617
# 2021               10961            7985        11709        14302
# 2022               12295            9583        12089        15220
# 2023               13174           10699        12879        15326
#
# ...

# %%
df = helper.get_helper(data, 'Transportation', 1) / helper.get_helper(data, 'Income after taxes', 1)
grapher.graph_all(df, "Average of Transportation Costs Normalized By Income", columns)
df
# Out:
# Error in get_heat_plot: 'bool' object has no attribute 'all'
#       All consumer units  Under 25 years  25-34 years  35-44 years  \
# Year
# 2012            0.141991        0.190377     0.169299     0.130813
# 2013            0.159781        0.213562     0.172684     0.152114
# 2014            0.155455        0.216249     0.163084     0.146451
# 2015            0.157210        0.213427     0.170706     0.149973
# 2016            0.141005        0.129565     0.155007     0.130590
# 2017            0.150552        0.222130     0.149072     0.146200
# 2018            0.145164        0.185480     0.159754     0.143714
# 2019            0.150265        0.233431     0.151664     0.152929
# 2020            0.131102        0.171789     0.140256     0.136117
# 2021            0.139200        0.179887     0.149705     0.146064
# 2022            0.147785        0.206357     0.149411     0.147087
# 2023            0.149928        0.208647     0.151626     0.140509
#
# ...

# %%
df = helper.get_helper(data, 'Transportation', 2)
grapher.graph_all(df, "Share of Transportation Costs", columns)
df
# Out:
# Error in get_heat_plot: 'bool' object has no attribute 'all'
#       All consumer units  Under 25 years  25-34 years  35-44 years  \
# Year
# 2012                17.5            20.4         19.6         17.2
# 2013                17.6            18.7         19.1         17.9
# 2014                17.0            19.2         18.0         17.0
# 2015                17.0            19.3         18.8         16.8
# 2016                15.8            17.5         17.3         15.6
# 2017                15.9            19.8         16.5         16.0
# 2018                15.9            17.2         18.3         16.6
# 2019                17.0            21.1         18.0         18.3
# 2020                16.0            19.2         17.8         17.0
# 2021                16.4            19.0         18.3         17.9
# 2022                16.8            20.7         17.8         17.7
# 2023                17.0            21.6         17.9         16.9
#
# ...

# %% [markdown]
# #### Healthcare

# %%
df = helper.get_helper(data, 'Healthcare', 1)
grapher.graph_all(df, "Mean of Healthcare Expenditures", columns)
df
# Out:
# Error in get_heat_plot: 'bool' object has no attribute 'all'
#       All consumer units  Under 25 years  25-34 years  35-44 years  \
# Year
# 2013                3631             943         2189         3188
# 2014                4290            1103         2659         4033
# 2015                4342             978         2770         3873
# 2016                4612            1162         2887         4076
# 2017                4928            1547         3163         4348
# 2018                4968            1206         3072         4317
# 2019                5193            1510         3162         4822
# 2020                5177            1350         3320         4579
# 2021                5452            1367         3404         5142
# 2022                5850            1353         3560         5329
# 2023                6159            1723         3532         5509
#
#       45-54 years  55-64 years  65 years and older  65-74 years  \
# Year
# ...

# %%
df = helper.get_helper(data, 'Healthcare', 2)
grapher.graph_all(df, "Share of Healthcare Expenditures", columns)
df
# Out:
# Error in get_heat_plot: 'bool' object has no attribute 'all'
#       All consumer units  Under 25 years  25-34 years  35-44 years  \
# Year
# 2013                 7.1             3.1          4.6          5.4
# 2014                 8.0             3.4          5.4          6.5
# 2015                 7.8             3.0          5.3          5.9
# 2016                 8.0             3.4          5.5          6.1
# 2017                 8.2             4.6          5.7          6.3
# 2018                 8.1             3.8          5.4          6.1
# 2019                 8.2             3.8          5.5          6.4
# 2020                 8.4             3.5          5.8          6.2
# 2021                 8.1             3.3          5.3          6.5
# 2022                 8.0             2.9          5.2          6.2
# 2023                 8.0             3.5          4.9          6.1
#
#       45-54 years  55-64 years  65 years and older  65-74 years  \
# Year
# ...

# %%
df = helper.get_helper(data, 'Healthcare', 1) / helper.get_helper(data, 'Income after taxes', 1)
grapher.graph_all(df, "Ratio of Healthcare Expenditure To Income", columns)
df
# Out:
# Error in get_heat_plot: 'bool' object has no attribute 'all'
#       All consumer units  Under 25 years  25-34 years  35-44 years  \
# Year
# 2012                 NaN             NaN          NaN          NaN
# 2013            0.064434        0.035506     0.041164     0.046101
# 2014            0.073504        0.038677     0.048680     0.055631
# 2015            0.071830        0.033027     0.048364     0.053069
# 2016            0.071866        0.024918     0.049047     0.051419
# 2017            0.077477        0.051636     0.051729     0.057506
# 2018            0.073883        0.040479     0.047615     0.052400
# 2019            0.072643        0.042442     0.046577     0.053886
# 2020            0.069074        0.031769     0.045310     0.049400
# 2021            0.069238        0.030796     0.043522     0.052514
# 2022            0.070317        0.029135     0.043999     0.051500
# 2023            0.070093        0.033601     0.041583     0.050507
#
# ...
